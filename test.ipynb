# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784).astype('float32') / 255.0
X_test = X_test.reshape(10000, 784).astype('float32') / 255.0
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

model = Sequential()
model.add(Dense(units=64, input_dim=28*28, activation='relu'))
model.add(Dense(units=10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(X_train, Y_train, epochs=5, batch_size=32)

loss_and_metrics = model.evaluate(X_test, Y_test, batch_size=32)

print('loss_and_metrics : ' + str(loss_and_metrics))
# Out:
# Epoch 1/5
#  - ETA: 2s - loss: 1.5807 - accuracy: 0.5472
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3681 - accuracy: 0.8988
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3062 - accuracy: 0.9134
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2784 - accuracy: 0.9207
# Epoch 5/5
#  - ETA: 1s - loss: 0.2559 - accuracy: 0.9281
# 313/313 [==============================] - 0s 967us/step - loss: 0.2337 - accuracy: 0.9341
# loss_and_metrics : [0.23365356028079987, 0.9340999722480774]

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
