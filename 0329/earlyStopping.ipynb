# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np

np.random.seed(3)

# 1. 데이터셋 준비하기

# 훈련셋과 시험셋 로딩
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# 훈련셋과 검증셋 분리
X_val = X_train[50000:]
Y_val = Y_train[50000:]
X_train = X_train[:50000]
Y_train = Y_train[:50000]

X_train = X_train.reshape(50000, 784).astype('float32') / 255.0
X_val = X_val.reshape(10000, 784).astype('float32') / 255.0
X_test = X_test.reshape(10000, 784).astype('float32') / 255.0

# 훈련셋, 검증셋 고르기
train_rand_idxs = np.random.choice(50000, 700)
val_rand_idxs = np.random.choice(10000, 300)

X_train = X_train[train_rand_idxs]
Y_train = Y_train[train_rand_idxs]
X_val = X_val[val_rand_idxs]
Y_val = Y_val[val_rand_idxs]

# 라벨링 전환
Y_train = np_utils.to_categorical(Y_train)
Y_val = np_utils.to_categorical(Y_val)
Y_test = np_utils.to_categorical(Y_test)

# 2. 모델 구성하기
model = Sequential()
model.add(Dense(units=2, input_dim=28*28, activation='relu'))
model.add(Dense(units=10, activation='softmax'))

# 3. 모델 엮기
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# 4. 모델 학습시키기
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping() # 조기종료 콜백함수 정의
hist = model.fit(X_train, Y_train, epochs=3000, batch_size=10, validation_data=(X_val, Y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/3000
# 70/70 [==============================] - 1s 15ms/step - loss: 2.3184 - accuracy: 0.0698 - val_loss: 2.3035 - val_accuracy: 0.0900
# Epoch 2/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.3025 - accuracy: 0.1277 - val_loss: 2.3031 - val_accuracy: 0.0933
# Epoch 3/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.3012 - accuracy: 0.1241 - val_loss: 2.2972 - val_accuracy: 0.0967
# Epoch 4/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.2856 - accuracy: 0.1047 - val_loss: 2.2289 - val_accuracy: 0.1100
# Epoch 5/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.2318 - accuracy: 0.0936 - val_loss: 2.1809 - val_accuracy: 0.1767
# Epoch 6/3000
# 70/70 [==============================] - 0s 3ms/step - loss: 2.1922 - accuracy: 0.1296 - val_loss: 2.1387 - val_accuracy: 0.2000
# Epoch 7/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.1664 - accuracy: 0.1784 - val_loss: 2.1043 - val_accuracy: 0.2000
# Epoch 8/3000
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1316 - accuracy: 0.1785 - val_loss: 2.0763 - val_accuracy: 0.1933
# Epoch 9/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.1265 - accuracy: 0.1946 - val_loss: 2.0556 - val_accuracy: 0.2167
# Epoch 10/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.0980 - accuracy: 0.1936 - val_loss: 2.0327 - val_accuracy: 0.2100
# Epoch 11/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.0677 - accuracy: 0.2028 - val_loss: 2.0159 - val_accuracy: 0.2233
# Epoch 12/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.0561 - accuracy: 0.2072 - val_loss: 2.0001 - val_accuracy: 0.2267
# Epoch 13/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 2.0247 - accuracy: 0.2144 - val_loss: 1.9872 - val_accuracy: 0.2267
# Epoch 14/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.0387 - accuracy: 0.2171 - val_loss: 1.9751 - val_accuracy: 0.2233
# Epoch 15/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 2.0235 - accuracy: 0.1940 - val_loss: 1.9648 - val_accuracy: 0.2333
# Epoch 16/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9966 - accuracy: 0.2167 - val_loss: 1.9557 - val_accuracy: 0.2400
# Epoch 17/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9580 - accuracy: 0.2231 - val_loss: 1.9479 - val_accuracy: 0.2400
# Epoch 18/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9714 - accuracy: 0.2262 - val_loss: 1.9414 - val_accuracy: 0.2467
# Epoch 19/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9565 - accuracy: 0.2103 - val_loss: 1.9326 - val_accuracy: 0.2433
# Epoch 20/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9560 - accuracy: 0.2262 - val_loss: 1.9277 - val_accuracy: 0.2533
# Epoch 21/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9454 - accuracy: 0.2070 - val_loss: 1.9209 - val_accuracy: 0.2467
# Epoch 22/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9610 - accuracy: 0.2027 - val_loss: 1.9155 - val_accuracy: 0.2433
# Epoch 23/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 1.9385 - accuracy: 0.2262 - val_loss: 1.9115 - val_accuracy: 0.2367
# Epoch 24/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9276 - accuracy: 0.2074 - val_loss: 1.9049 - val_accuracy: 0.2467
# Epoch 25/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9009 - accuracy: 0.2124 - val_loss: 1.9014 - val_accuracy: 0.2267
# Epoch 26/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9681 - accuracy: 0.2002 - val_loss: 1.8947 - val_accuracy: 0.2433
# Epoch 27/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9014 - accuracy: 0.2142 - val_loss: 1.8917 - val_accuracy: 0.2400
# Epoch 28/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8867 - accuracy: 0.2369 - val_loss: 1.8877 - val_accuracy: 0.2333
# Epoch 29/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.9021 - accuracy: 0.2356 - val_loss: 1.8836 - val_accuracy: 0.2367
# Epoch 30/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8773 - accuracy: 0.2066 - val_loss: 1.8802 - val_accuracy: 0.2367
# Epoch 31/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8696 - accuracy: 0.2263 - val_loss: 1.8767 - val_accuracy: 0.2333
# Epoch 32/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8768 - accuracy: 0.2266 - val_loss: 1.8729 - val_accuracy: 0.2300
# Epoch 33/3000
# 70/70 [==============================] - 0s 2ms/step - loss: 1.8994 - accuracy: 0.2243 - val_loss: 1.8709 - val_accuracy: 0.2300
# Epoch 34/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8914 - accuracy: 0.2230 - val_loss: 1.8670 - val_accuracy: 0.2367
# Epoch 35/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8650 - accuracy: 0.2416 - val_loss: 1.8646 - val_accuracy: 0.2267
# Epoch 36/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8826 - accuracy: 0.2083 - val_loss: 1.8605 - val_accuracy: 0.2300
# Epoch 37/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8750 - accuracy: 0.2441 - val_loss: 1.8585 - val_accuracy: 0.2333
# Epoch 38/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8605 - accuracy: 0.2334 - val_loss: 1.8561 - val_accuracy: 0.2333
# Epoch 39/3000
# 70/70 [==============================] - 0s 1ms/step - loss: 1.8282 - accuracy: 0.2433 - val_loss: 1.8566 - val_accuracy: 0.2233

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')

acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'g', label='val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
loss_and_metrics = model.evaluate(X_test, Y_test, batch_size=32)

print('')
print('loss : ' + str(loss_and_metrics[0]))
print('accuracy : ' + str(loss_and_metrics[1]))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 1.8714 - accuracy: 0.2341
#
# loss : 1.8713921308517456
# accuracy : 0.23409999907016754
